# %%
import os
import pickle
import numpy as np
from text_processing_utils import *
import glob
import math
from scipy.stats import pearsonr
import matplotlib.pyplot as plt

# %%
cleaned_ratings = np.array(pickle.load(open("data/scaledata/cleaned_ratings.pickle", "rb")))
cleaned_reviews = pickle.load(open("data/scaledata/cleaned_reviews.pickle", "rb"))
vocabulary_dict = pickle.load(open("data/scaledata/vocabulary_dict.pickle", "rb"))

# %%
# randomly split the movie reviews data into training/testing parts (80:20)
np.random.seed(7654321)
train_indices = np.random.choice(np.arange(len(cleaned_ratings)), int(len(cleaned_ratings)*0.8), replace=False)
test_indices = np.setdiff1d(np.arange(len(cleaned_ratings)), train_indices)
print(len(train_indices), len(test_indices))
train_bow = convert_bow([cleaned_reviews[i] for i in train_indices])
test_bow = convert_bow([cleaned_reviews[i] for i in test_indices])
train_y = cleaned_ratings[train_indices]
test_y = cleaned_ratings[test_indices]
# Out:
# 4004 1002

# %%
K = 24 # number of topics
V = len(vocabulary_dict) # vocabulary size

# %%
## Loading the optimized global parameters from the model training phase
np.random.seed(12345)
new_alpha = pickle.load(open("data/scaledata/K_{}/alpha.pickle".format(K), "rb"))
new_xi = pickle.load(open("data/scaledata/K_{}/xi.pickle".format(K), "rb"))
new_eta = pickle.load(open("data/scaledata/K_{}/eta.pickle".format(K), "rb"))
new_delta = pickle.load(open("data/scaledata/K_{}/delta.pickle".format(K), "rb"))
new_Lambda = pickle.load(open("data/scaledata/K_{}/Lambda.pickle".format(K), "rb"))

input_data_x = test_bow
input_data_y = test_y
fpath = "fragmented_output_files_new/" # where to store the temporary fragmented files during parallelized E steps
if not os.path.exists(fpath[:-1]):
    os.makedirs(fpath[:-1])
else:
    for fn in glob.glob(fpath + "*"):
        os.remove(fn)
epsilon = 1e-4 # stopping criteria for convergence in E step
predict = True # prediction mode for evaluating the test set

## Run one iteration of unsupervised E step (parallelized) to identify the optimal local variational parameters for all documents in the test set.
## The optimized phi identified from the unsupervised batch VI will be used to generate the predictions for response variable y in the test set
# %run -i "parallelized_sLDA_E_step.py" # unsupervised batch VI for sLDA is way faster than supervised one
all_gamma = [pickle.load(open(fn, "rb")) for fn in glob.glob(fpath + "gamma*")]
new_gamma_dict = merge_dict(all_gamma)
new_gamma = create_gamma_matrix(new_gamma_dict)
all_phi = [pickle.load(open(fn, "rb")) for fn in glob.glob(fpath + "phi*")]
new_phi = merge_dict(all_phi)

# %%
time_elapsed = pickle.load(open("data/scaledata/K_{}/time_elapsed.pickle".format(K), "rb"))
print("Time used to fit the sLDA model:", int(time_elapsed / 60), "minutes")
# Out:
# Time used to fit the sLDA model: 237 minutes

# %%
elbo_vs_time = pickle.load(open("data/scaledata/K_{}/elbo_vs_time.pickle".format(K), "rb"))
print(len(elbo_vs_time)-1)
plt.plot(np.arange(1, len(elbo_vs_time)), elbo_vs_time[1:])
plt.xlabel("Variation EM Iteration")
plt.ylabel("Corpus-level ELBO")
plt.show()
# Out:
# 61

# %%
# Topic words of each topic learned from training sLDA, with corresponding coefficients (eta)
inverse_vocabulary_dict = {v:k for k,v in vocabulary_dict.items()}
for t in range(K):
    word_indices = np.argsort(new_Lambda[t,:])[::-1][:10]
    print("Topic {}:".format(t+1), [inverse_vocabulary_dict[j] for j in word_indices], "eta =", new_eta[t])
# Out:
# Topic 1: ['emotional', 'art', 'visual', 'producers', 'despite', 'however', 'nearly', 'color', 'aspect', 'deep'] eta = 1.31036044964282
# Topic 2: ['movies', 'humor', 'why', 'ever', 'then', 'sex', 'comes', 'sexual', 'gives', 'old'] eta = 0.3611204456296484
# Topic 3: ['line', 'subject', 'men', 'style', 'subscribe', 'details', 'women', 'find', 'word', 'attempt'] eta = 0.7674899959713208
# Topic 4: ['seemed', 'clear', 'plenty', 'williams', 'fairly', 'chris', 'parker', 'kiss', 'creepy', 'terribly'] eta = -0.686860373922249
# Topic 5: ['through', 'where', 'feels', 'narrative', 'stories', 'yet', 'adult', 'mark', 'times', 'modern'] eta = 0.9095796544160848
# Topic 6: ['right', 'half', 'actually', 'watching', 'lines', 'works', 'going', 'along', 'believe', 'whose'] eta = 0.4034043438733903
# Topic 7: ['kids', 'son', 'pg', 'jeffrey', '10', 'laugh', 'thought', 'joke', 'call', 'bunch'] eta = 0.5537137774476548
# Topic 8: ['de', 'rich', 'oscar', 'colors', 'force', 'today', 'images', 'contrast', 'road', 'intense'] eta = 2.2689603737657578
# Topic 9: ['funny', 'plot', 'scene', 'since', 'almost', 'teenagers', 'seen', 'language', 'off', 've'] eta = 0.28625329180153436
# Topic 10: ['high', 'game', 'school', 'woody', 'debut', 'joe', 'basketball', 'affection', 'chases', 'forrest'] eta = 0.7385666058280442
# Topic 11: ['still', 'think', 'fun', 'anything', 'done', 'reason', '2', 'nice', 'manages', 'our'] eta = -0.10345362303651484
# Topic 12: ['thing', 'family', 'heart', 'beauty', 'kevin', 'using', 'taken', 'tragedy', 'child', 'period'] eta = 1.1107370231458091
# Topic 13: ['bad', 'play', 'least', 'interesting', 'sort', 'worse', 'guys', 'dull', 'came', 'fair'] eta = -1.4671824648499374
# Topic 14: ['comedy', 'him', 'artist', 'lawrence', 'eddie', 'roberts', 'niro', 'cynical', 'gag', 'neil'] eta = 0.12593297215068056
# Topic 15: ['man', 'comic', 'room', 'reply', 'situations', 'simply', 'screening', 'idea', 'himself', 'premise'] eta = 0.023655268606340485
# Topic 16: ['here', 'ending', 'itself', 'effort', 'noir', 'shown', 'telling', 'felt', 'eyes', 'lot'] eta = 0.6204545504388026
# Topic 17: ['set', 'watch', 'waste', 'sometimes', 'thriller', 'romance', 'opinions', 'second', 'let', 'completely'] eta = 0.7631899634710244
# Topic 18: ['give', 'before', 'rather', 'said', 'bond', '9', 'alive', 'tried', 'whatever', 'images'] eta = 0.5549800088788217
# Topic 19: ['year', 'long', 'acting', 'violence', 'great', 'end', 'must', 'go', 'fine', 'poor'] eta = 0.328889145071674
# Topic 20: ['music', 'history', 'allen', 'shakespeare', 'bergman', 'festival', 'climax', 'joy', 'filmmaker', 'maker'] eta = 1.451866954045144
# Topic 21: ['david', 'musical', 'leaves', 'animated', 'upon', 'adventure', 'reaction', 'number', 'america', 'amusing'] eta = 0.47858006921118523
# Topic 22: ['re', 'both', 'real', 'role', 'shot', 'hand', 'used', 'same', 'stone', 'killer'] eta = 0.5301680703514471
# Topic 23: ['really', 'world', 'say', 'over', 'minutes', 'less', 'sense', 'ca', 'given', 'cinematography'] eta = 0.7475727372045213
# Topic 24: ['gets', 'potential', 'country', 'ideas', 'boy', 'paul', 'dog', 'jack', 'frank', 'god'] eta = 0.9333436840330052
# Topic 25: ['john', 'special', 'effects', 'summer', 'villain', 'steven', 'familiar', 'pretty', 'science', 'awful'] eta = 0.7241666619160778
# Topic 26: ['seems', 'every', 'point', 'always', 'message', 'running', 'michael', 'piece', 'years', 'elements'] eta = 0.9578193053874244
# Topic 27: ['us', 'between', 'making', 'take', 'hollywood', 'dialogue', 'american', 'each', 'becomes', 'obvious'] eta = 0.2159639184874642
# Topic 28: ['actors', 'last', 'r', 'star', 'back', 'bit', 'worth', 'full', 'looks', 'profanity'] eta = 0.6181331741899925
# Topic 29: ['screen', 'far', 'new', 'often', 'viewers', 'themes', 'level', 'production', 'effective', 'hard'] eta = 0.6840437876478891
# Topic 30: ['though', 'things', 'three', 'tale', 'experience', 'someone', 'dark', 'documentary', 'own', 'mr'] eta = 0.6955441107974583
# Topic 31: ['love', 'disney', 's', 'features', 'adults', 'u', 'appealing', 'distributor', 'jones', 'delightful'] eta = 1.0847146089336661
# Topic 32: ['big', 'excellent', 'totally', 'age', 'recommend', 'average', 'lot', 'mine', 'expressed', '0'] eta = 1.1723507648859623
# Topic 33: ['know', 'horror', 'points', 'king', 'gay', 'scream', 'branagh', 'monster', 'ice', 'murphy'] eta = 0.8297269221877848
# Topic 34: ['action', 'again', 'sequences', 'genre', 'however', 'example', 'nothing', 'dead', 'series', 'certain'] eta = 0.011114253186127243
# Topic 35: ['human', 'different', 'title', 'viewer', 'difficult', 'taking', 'woman', 'dramatic', 'cinema', 'leave'] eta = 1.4102452815010729
# Topic 36: ['original', 'romantic', 'simple', 'keep', 'likely', 'serious', 'entertainment', 'home', 'close', 'tv'] eta = 0.6438605962397048

# %%
# Generate predictions for the response variable y for the test set:
# For Gaussian response, y_hat = E[phi_bar^T eta]
phi_bar = {k:v.mean(axis=0) for k,v in new_phi.items()}
pred_y = np.empty((len(test_y),))
for indx in range(len(test_y)):
    pred_y[indx] = np.dot(phi_bar[indx], new_eta)

# %%
# performance metrics: 
def predictive_R2(test_y, pred_y):
    return 1 - np.mean((test_y - pred_y)**2) / np.var(test_y)

print("Predictive R^2 =", predictive_R2(test_y, pred_y))
print("Pearson correlation coefficient =", pearsonr(test_y, pred_y).statistic)
# Out:
# Predictive R^2 = 0.1869059803755514
# Pearson correlation coefficient = 0.43325864600685615

# %%
# Compare the predicted histogram of predicted vs. actual y values 
plt.hist(pred_y, alpha=0.5, label='x')
plt.hist(test_y, alpha=0.5, label='y')
plt.legend(['predicted y', 'actual_y'], loc='upper right')
plt.show()
