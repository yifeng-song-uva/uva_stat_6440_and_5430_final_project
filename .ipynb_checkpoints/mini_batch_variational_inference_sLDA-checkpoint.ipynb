# %%
from scipy.special import polygamma

# %%
class mini_batch_VI_sLDA:
    
    def __init__self(self, bow, alpha, eta, delta):
        self.bow = self.bow
        self.alpha = alpha
        self.eta = eta
        self.delta = delta
        self.M = len(self.bow) #batch_size: # of documents
        self.gamma = None
        self.phi = None
        self.lambda = None
        
    def update_gamma(self):
        pass

    def update_phi_unsupervised(self):
        pass

    def update_phi_supervised(self):
        pass

    def update_lambda(self):
        pass

    def coordinate_ascent(self):
        pass
