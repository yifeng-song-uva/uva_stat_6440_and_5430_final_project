# %% [markdown]
# Upload the 5 Python scripts (text_processing_utils.py, variational_inference_utils.py, variational_inference_sLDA_E_step.py, variational_inference_sLDA_M_step.py, parallelized_sLDA_E_step.py) to the same (temporary runtime) directory as this Google Colab notebook. Also, need to upload the movie reviews/rating data to my Google Drive Home Directory using the structure "data/scaledata/xxx.pickle".

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import pickle
import numpy as np
from text_processing_utils import *
import glob
import datetime as dt
import math
from variational_inference_sLDA_M_step import *
start_time = dt.datetime.now()

# %%
cleaned_ratings = np.array(pickle.load(open("/content/drive/MyDrive/data/scaledata/cleaned_ratings.pickle", "rb")))
cleaned_reviews = pickle.load(open("/content/drive/MyDrive/data/scaledata/cleaned_reviews.pickle", "rb"))
vocabulary_dict = pickle.load(open("/content/drive/MyDrive/data/scaledata/vocabulary_dict.pickle", "rb"))

# %%
# randomly split the movie reviews data into training/testing parts (80:20)
np.random.seed(54321)
train_indices = np.random.choice(np.arange(len(cleaned_ratings)), int(len(cleaned_ratings)*0.8), replace=False)
test_indices = np.setdiff1d(np.arange(len(cleaned_ratings)), train_indices)
print(len(train_indices), len(test_indices))
train_bow = convert_bow([cleaned_reviews[i] for i in train_indices])
test_bow = convert_bow([cleaned_reviews[i] for i in test_indices])
train_y = cleaned_ratings[train_indices]
test_y = cleaned_ratings[test_indices]
# Out:
# 4004 1002

# %%
K = 36 # number of topics
V = len(vocabulary_dict) # vocabulary size

# %%
## initialization
np.random.seed(12345)
new_alpha = np.array([1/K]*K)
new_xi = np.array([1/V]*V)
new_eta = np.linspace(-1,1,K)
new_delta = np.var(train_y, ddof=1)
new_Lambda = np.abs(np.random.normal(loc=0, scale=0.1, size=K*V)).reshape((K,V)) # initialize Lambda randomly (add a small half-normal distribution to 1)
input_data_x = train_bow
input_data_y = train_y
fpath = "fragmented_output_files/" # where to store the temporary fragmented files during parallelized E steps
if not os.path.exists(fpath[:-1]):
    os.makedirs(fpath[:-1])
epsilon = 1e-4 # stopping criteria for convergence in E step
predict = False
## Run batch mode variational EM
elbo_vs_time = [-math.inf]
improve_in_elbo = math.inf
time_elapsed = 0
j = 0
while improve_in_elbo > 0.01 and time_elapsed < 23.5 * 3600: # there's a time limit to the Google Colab Pro+

    ### Run one iteration of E step (parallelized)
    # %run -i "parallelized_sLDA_E_step.py"
    all_gamma = [pickle.load(open(fn, "rb")) for fn in glob.glob(fpath + "gamma*")]
    new_gamma_dict = merge_dict(all_gamma)
    new_gamma = create_gamma_matrix(new_gamma_dict)
    all_phi = [pickle.load(open(fn, "rb")) for fn in glob.glob(fpath + "phi*")]
    new_phi = merge_dict(all_phi)

    ### Run one iteration of M step
    m_step = batch_VI_sLDA_M_Step(K, train_bow, train_y,
                                  new_alpha, new_xi, new_eta, new_delta, new_Lambda,
                                  new_gamma, new_phi,
                                  len(train_bow), 1e-4)
    new_Lambda, new_alpha, new_xi, new_eta, new_delta, new_elbo = m_step.run()
    improve_in_elbo = pct_diff(elbo_vs_time[-1], new_elbo)
    elbo_vs_time.append(new_elbo)
    current_time = dt.datetime.now()
    time_elapsed = (current_time - start_time).seconds
    j += 1
    print("variational EM iteration {}: elbo =".format(j), new_elbo)

## save final results to Google Drive
output_dir = "/content/drive/MyDrive/batch_VI_sLDA_movie_rating/K_{}".format(K)
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
for var in ['Lambda', 'alpha', 'xi', 'eta', 'delta']:
    pickle.dump(eval("new_"+var), open(output_dir + "/{}.pickle".format(var), "wb"))
pickle.dump(elbo_vs_time, open(output_dir + "/{}.pickle".format("elbo_vs_time"), "wb"))
pickle.dump(time_elapsed, open(output_dir + "/{}.pickle".format("time_elapsed"), "wb"))
# Out:
# variational EM iteration 1: elbo = -7009122.203960896
# variational EM iteration 2: elbo = -6161750.460046768
# variational EM iteration 3: elbo = -5898617.193649769
# variational EM iteration 4: elbo = -5767621.487053871
# variational EM iteration 5: elbo = -5687366.896230698
# variational EM iteration 6: elbo = -5631689.78215456
# variational EM iteration 7: elbo = -5590519.80180788
# variational EM iteration 8: elbo = -5557318.078656197
# variational EM iteration 9: elbo = -5528668.945659637
# variational EM iteration 10: elbo = -5502891.914651871
# variational EM iteration 11: elbo = -5479926.350068569
# variational EM iteration 12: elbo = -5459148.320565224
# variational EM iteration 13: elbo = -5440250.07695961
# variational EM iteration 14: elbo = -5423149.096399546
# variational EM iteration 15: elbo = -5407853.93422699
# variational EM iteration 16: elbo = -5394251.390274763
# variational EM iteration 17: elbo = -5382198.821063757
# variational EM iteration 18: elbo = -5371341.338031054
# variational EM iteration 19: elbo = -5361836.152211428
# variational EM iteration 20: elbo = -5353555.5080964565
# variational EM iteration 21: elbo = -5346141.69045043
# variational EM iteration 22: elbo = -5339633.983186007
# variational EM iteration 23: elbo = -5333785.121650696
# variational EM iteration 24: elbo = -5328285.938875437
# variational EM iteration 25: elbo = -5323254.518643618
# variational EM iteration 26: elbo = -5318844.6512134075
# variational EM iteration 27: elbo = -5314755.129067659
# variational EM iteration 28: elbo = -5311140.46729517
# variational EM iteration 29: elbo = -5307743.62526989
# variational EM iteration 30: elbo = -5304615.016019344
# variational EM iteration 31: elbo = -5301758.499323368
# variational EM iteration 32: elbo = -5299169.295985699
# variational EM iteration 33: elbo = -5296760.694926977
# variational EM iteration 34: elbo = -5294518.532616138
# variational EM iteration 35: elbo = -5292481.960421085
# variational EM iteration 36: elbo = -5290545.595585585
# variational EM iteration 37: elbo = -5288812.939290047
# variational EM iteration 38: elbo = -5287223.45740211
# variational EM iteration 39: elbo = -5285703.469125509
# variational EM iteration 40: elbo = -5284208.508821368
# variational EM iteration 41: elbo = -5282816.704834223
# variational EM iteration 42: elbo = -5281530.419503689
# variational EM iteration 43: elbo = -5280310.177276492
# variational EM iteration 44: elbo = -5279174.752654672
# variational EM iteration 45: elbo = -5278075.707012057
# variational EM iteration 46: elbo = -5277004.18597281
# variational EM iteration 47: elbo = -5275965.525143504
# variational EM iteration 48: elbo = -5275008.703019381
# variational EM iteration 49: elbo = -5274101.236440182
# variational EM iteration 50: elbo = -5273247.768808007
# variational EM iteration 51: elbo = -5272470.750350952
# variational EM iteration 52: elbo = -5271685.010315537
# variational EM iteration 53: elbo = -5270924.435625792
# variational EM iteration 54: elbo = -5270220.93095994
# variational EM iteration 55: elbo = -5269519.272274733
# variational EM iteration 56: elbo = -5268846.744159818
# variational EM iteration 57: elbo = -5268205.033628464
# variational EM iteration 58: elbo = -5267545.520949841
# variational EM iteration 59: elbo = -5266920.678872228
# variational EM iteration 60: elbo = -5266326.400412798
# variational EM iteration 61: elbo = -5265743.362614989
# variational EM iteration 62: elbo = -5265201.579290032
# variational EM iteration 63: elbo = -5264663.268544555
# variational EM iteration 64: elbo = -5264159.433042288
